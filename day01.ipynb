# %% [markdown]
# <a href="https://colab.research.google.com/github/rajendra0968jangid/Aws-ML-arya/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajendra")
# Out:
# rajendra
